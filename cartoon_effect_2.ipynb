# %% [markdown]
# <a href="https://colab.research.google.com/github/viadean/-Infrastructor-Kubernetes-/blob/master/cartoon_effect_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
from google.colab import files

# %%
def read_file(filename):
  img = cv2.imread(filename)
  cv2_imshow(img)
  return img

# %%
def color_quantization(img, k):
# Transform the image
  data = np.float32(img).reshape((-1, 3))

# Determine criteria
  criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 20, 0.001)

# Implementing K-Means
  ret, label, center = cv2.kmeans(data, k, None, criteria, 10, cv2.KMEANS_RANDOM_CENTERS)
  center = np.uint8(center)
  result = center[label.flatten()]
  result = result.reshape(img.shape)
  return result

# %%
def edge_mask(img, line_size, blur_value):
  gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  gray_blur = cv2.medianBlur(gray, blur_value)
  edges = cv2.adaptiveThreshold(gray_blur, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, line_size, blur_value)
  return edges

# %% [markdown]
# **Upload Image File**

# %%
uploaded = files.upload()

filename = next(iter(uploaded))
img = read_file(filename)

# %% [markdown]
# **Run Code to Create Cartoon Effect**

# %%
line_size = 7
blur_value = 7

edges = edge_mask(img, line_size, blur_value)
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=L size=640x958 at 0x7F6AC14FC7F0>

# %%
total_color = 9

img = color_quantization(img, total_color)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=640x958 at 0x7F6AC14FC6A0>
# <PIL.Image.Image image mode=RGB size=640x958 at 0x7F6AC14FC4E0>

# %%
blurred = cv2.bilateralFilter(img, d=7, sigmaColor=200,sigmaSpace=200)
cv2_imshow(blurred)
# Out:
# <PIL.Image.Image image mode=RGB size=640x958 at 0x7F6AC14FC9B0>

# %%
cartoon = cv2.bitwise_and(blurred, blurred, mask=edges)
cv2_imshow(cartoon)
# Out:
# <PIL.Image.Image image mode=RGB size=640x958 at 0x7F6AC14FC7F0>
